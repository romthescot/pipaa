# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

# %%
def sectorDynamics(vx, t, B, M, P, alpha, mu):

    x, y = vx

    #payoffMatrix
    pm = [[B-M+ alpha, B-P-alpha, -M, 0],
         [0, -P, 0, 0]]
    
     #fitness difference in the 3 sectors
    airportsDiff  = y*(pm[0][0]-pm[1][0])+(1-y)*(pm[0][2]-pm[1][2])
    airlinesDiff = x*(pm[0][1]-pm[0][3])+(1-x)*(pm[1][1]-pm[1][3])
    
    #replicator dynamics
    x1 = x*(1-x)*((airportsDiff))*(1-mu) + (1-2*x)*mu
    x2 = y*(1-y)*((airlinesDiff))*(1-mu) + (1-2*y)*mu

    dxdt = [x1, x2]

    return dxdt

# %%
# initial conditions: 10% of each sector adopts 
x0 = [0.28, 0.1]

t1 = np.linspace(0, 500, 100)
sol1 = odeint(sectorDynamics, x0, t1, args=(0.25, 0.1, 0, 0.11, 0.000))

# %%
#plot
#plt.subplot(222)
plt.plot(t1, sol1[:, 0], 'b', label='airports(t)')
plt.plot(t1, sol1[:, 1], 'r', label='airlines(t)')
plt.xlabel('t')
plt.legend(loc='best')
plt.title('Evolution of H2 techonology when only the cost of airlines is subsidized by the regulator')
# Out:
# Text(0.5, 1.0, 'Evolution of H2 techonology when only the cost of airlines is subsidized by the regulator')
